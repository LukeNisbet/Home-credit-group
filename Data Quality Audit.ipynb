# %%
import pandas as pd
from pydqc import infer_schema, data_summary, data_compare, data_consist

# See https://github.com/SauceCat/pydqc for full information on install etc
# https://stackoverflow.com/questions/46076754/use-package-from-github-in-conda-virtual-environment

# %%
applications = pd.read_pickle('C:\\Users\\luken\\Documents\\Home Credit Group\\Data\\app_features.pkl')
applications.sample(10)
# Out:
#             AMT_ANNUITY  AMT_CREDIT  AMT_GOODS_PRICE  AMT_INCOME_TOTAL  \
# SK_ID_CURR
# 338159          27153.0    254700.0         225000.0           90000.0
# 183004          25537.5    545040.0         450000.0          112500.0
# 151590          11682.0    119925.0         112500.0           99000.0
# 437440          13500.0    270000.0         270000.0          225000.0
# 317536          16983.0    183784.5         148500.0          180000.0
# 173983           9742.5    364428.0         238500.0          162000.0
# 114842          12586.5    119893.5         103500.0           67500.0
# 347338          52686.0    500490.0         450000.0          405000.0
# 429957          31167.0    797557.5         688500.0           99000.0
# 168726          17428.5    338832.0         292500.0           90000.0
#
#             AMT_REQ_CREDIT_BUREAU_DAY  AMT_REQ_CREDIT_BUREAU_HOUR  \
# SK_ID_CURR
# 338159                            NaN                         NaN
# ...

# %%
infer_schema.infer_schema(data=applications, fname='apps', output_root=r'C:\Users\luken\December 2018 Work', 
                          sample_size=0.1, type_threshold=0.5, n_jobs=2, base_schema=None)
print("Schema Infered!")

# %%
app_schema = pd.read_excel(r'C:\Users\luken\December 2018 Work\data_schema_apps2.xlsx')
app_schema.sample(10)
# Out:
#                                                 column     type  include  \
# 445  SUM(pre_app.MEAN(pos_cash.CNT_INSTALMENT_FUTURE))  numeric        1
# 268             MAX(install_pay.NUM_INSTALMENT_NUMBER)  numeric        1
# 449                SUM(pre_app.STD(cc_bal.SK_ID_CURR))  numeric        1
# 209                            MAX(pre_app.AMT_CREDIT)  numeric        1
# 775         MEAN(pre_app.MAX(pos_cash.MONTHS_BALANCE))  numeric        1
# 340                          STD(cc_bal.AMT_RECIVABLE)  numeric        1
# 643  MAX(pre_app.MEAN(install_pay.DAYS_ENTRY_PAYMENT))  numeric        1
# 365                   MAX(cc_bal.CNT_DRAWINGS_CURRENT)  numeric        1
# 338              STD(cc_bal.AMT_PAYMENT_TOTAL_CURRENT)  numeric        1
# 684                    MAX(pre_app.SUM(cc_bal.SK_DPD))  numeric        1
#
#                                           sample_value  sample_num_uni  \
# 445  [20.116666666666667, 5.444444444444445, 46.5, ...           12949
# ...

# %%
data_summary.data_summary(table_schema=app_schema
                                   ,table=applications
                                   ,fname='applications'
                                   ,sample_size=1.0
                                   ,output_root=r'C:\Users\luken\December 2018 Work'
                                   ,keep_images=False
                                   ,n_jobs=2
                                  )
